# %% [markdown]
# ## Entregable Actividad 06
#
# - **Fuente de datos**
# - **Intro**
# - **Objetivo** Establecer conexion con apis publicas

# %%
import requests

## definir la url
url = "https://apiv3.iucnredlist.org/api/v3/species/page/0?token=9bb4facb6d23f48efbf424bb05c0c1ef1cf6f468393bc745d42179ac4aca5fee"

headers = {"Acept-Version": "3"}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'count': 10000,
#  'page': '0',
#  'result': [{'taxonid': 3,
#    'kingdom_name': 'ANIMALIA',
#    'phylum_name': 'MOLLUSCA',
#    'class_name': 'GASTROPODA',
#    'order_name': 'STYLOMMATOPHORA',
#    'family_name': 'ENDODONTIDAE',
#    'genus_name': 'Aaadonta',
#    'scientific_name': 'Aaadonta angaurana',
#    'taxonomic_authority': 'Solem, 1976',
#    'infra_rank': None,
#    'infra_name': None,
#    'population': None,
#    'category': 'CR',
#    'main_common_name': None},
#   {'taxonid': 4,
#    'kingdom_name': 'ANIMALIA',
#    'phylum_name': 'MOLLUSCA',
#    'class_name': 'GASTROPODA',
#    'order_name': 'STYLOMMATOPHORA',
#    'family_name': 'ENDODONTIDAE',
#    'genus_name': 'Aaadonta',
#    'scientific_name': 'Aaadonta constricta',
#    'taxonomic_authority': '(Semper, 1874)',
#    'infra_rank': None,
#    'infra_name': None,
#    'population': None,
#    'category': 'EN',
#    'main_common_name': None},
#   {'taxonid': 5,
#    'kingdom_name': 'ANIMALIA',
# ...

# %%
import requests
import pandas as pd

url = "https://apiv3.iucnredlist.org/api/v3/species/page/0?token=9bb4facb6d23f48efbf424bb05c0c1ef1cf6f468393bc745d42179ac4aca5fee"
headers = {"Accept-Encoding": "gzip, deflate"}

response = requests.get(url, headers=headers)
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data.keys()
# Out:
# dict_keys(['count', 'page', 'result'])

# %%
data['result']
# Out:
# [{'taxonid': 3,
#   'kingdom_name': 'ANIMALIA',
#   'phylum_name': 'MOLLUSCA',
#   'class_name': 'GASTROPODA',
#   'order_name': 'STYLOMMATOPHORA',
#   'family_name': 'ENDODONTIDAE',
#   'genus_name': 'Aaadonta',
#   'scientific_name': 'Aaadonta angaurana',
#   'taxonomic_authority': 'Solem, 1976',
#   'infra_rank': None,
#   'infra_name': None,
#   'population': None,
#   'category': 'CR',
#   'main_common_name': None},
#  {'taxonid': 4,
#   'kingdom_name': 'ANIMALIA',
#   'phylum_name': 'MOLLUSCA',
#   'class_name': 'GASTROPODA',
#   'order_name': 'STYLOMMATOPHORA',
#   'family_name': 'ENDODONTIDAE',
#   'genus_name': 'Aaadonta',
#   'scientific_name': 'Aaadonta constricta',
#   'taxonomic_authority': '(Semper, 1874)',
#   'infra_rank': None,
#   'infra_name': None,
#   'population': None,
#   'category': 'EN',
#   'main_common_name': None},
#  {'taxonid': 5,
#   'kingdom_name': 'ANIMALIA',
#   'phylum_name': 'MOLLUSCA',
#   'class_name': 'GASTROPODA',
# ...

# %%
data[data]['taxonic']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data[data]['taxonic']
#
# TypeError: unhashable type: 'dict'
