# %% [markdown]
# # Entregable Actividad 01
#
# - **Fuente de datos**: https://rndc.mintransporte.gov.co/MenuPrincipal/tabid/204
# - **Intro**: Leer archivos mediante las librerias pandas.
# - **Objetivo principal**: identificar los reportes generados al ano y mes de registros urbanos y nacionales, con su numero de manifiesto,fecha expedicion,origen de manifiesto,destino de manifiesto,valor del flete, numero de placa, cedula conductor vehiculo, nombre conductor del vehiculo.

# %%
## Importancion de librerias para el desarrollo de la actividad

import pandas as pd 
import numpy as np
import os 
import warnings
warnings.filterwarnings("ignore")

# %%
path=os.getcwd() ## obtner la ruta del trabajo actual 
print(os.listdir()) ## listar los archiuvos del directorio
# Out:
# ['01-Desarrollo-data-portencial.ipynb', 'Data_RNDC.csv', 'Data_rndc_year_2024.csv', 'netflix_titles.csv']

# %%
## Lista de comprension con el proposito de filtrar solo aquellos que contienen la cadena Data_ y lo selecciona
file_name=[x for x in os.listdir() if 'Data_rndc_year' in x][0] 
## Arroja resultado del filtro
file_name
# Out:
# 'Data_rndc_year_2024.csv'

# %% [markdown]
# En el codigo anterior importamos las librerias que nos ayudaran apara poder leer el archivo con el que trabajaremos, adiconal a eso obtendremos la ruta, listaremos, localizaremos y mostraemos el directio u archivo sobre el que trabajeremos

# %% [markdown]
# ## Extraccion de los datos

# %%
## Lectura de archivo y encoding
rndc=pd.read_csv(path+ '\\' +  file_name,sep=";",encoding='utf-8')
##Resultado de lectura
rndc
# Out:
#         Item       Fecha        Sucursal     Origen    Destino        Nit  \
# 0          1   2/01/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 1          2   2/01/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 2          3   2/01/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 3          4   2/01/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 4          5   2/01/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# ...      ...         ...             ...        ...        ...        ...
# 18561  18562  31/12/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 18562  18563  31/12/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 18563  18564  31/12/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
# 18564  18565  31/12/2024  OPAV TOCANCIPA  TOCANCIPA  TOCANCIPA  891401858
# 18565  18566  31/12/2024      ATA BOGOTA     BOGOTA     BOGOTA  900294923
#
#                                    Cliente  Categoria  Orden de Servicio  \
# 0                   AVICOLA TRIPLE A S.A.S        NaN               5835
# 1                   AVICOLA TRIPLE A S.A.S        NaN               5836
# 2                   AVICOLA TRIPLE A S.A.S        NaN               5837
# 3                   AVICOLA TRIPLE A S.A.S        NaN               5838
# 4                   AVICOLA TRIPLE A S.A.S        NaN               5839
# ...                                    ...        ...                ...
# 18561               AVICOLA TRIPLE A S.A.S        NaN              25661
# 18562               AVICOLA TRIPLE A S.A.S        NaN              25663
# 18563               AVICOLA TRIPLE A S.A.S        NaN              25662
# 18564  OPERADORA AVICOLA DE COLOMBIA S.A.S        NaN              25707
# 18565               AVICOLA TRIPLE A S.A.S        NaN              25664
#
#       Doc. Cliente  ...  Nit REmite  \
# 0            H5000  ...  9002949239
# 1            H5000  ...  9002949239
# 2            H5000  ...  9002949239
# 3            H5000  ...  9002949239
# 4            H5001  ...  9002949239
# ...            ...  ...         ...
# 18561        H5000  ...  9002949239
# 18562        H5000  ...  9002949239
# 18563        H5000  ...  9002949239
# 18564         5874  ...   891401858
# 18565        H5000  ...  9002949239
#
#                                        Nombre Remite  \
# 0                            AVICOLA TRIPLE A S.A.S.
# 1                            AVICOLA TRIPLE A S.A.S.
# 2                            AVICOLA TRIPLE A S.A.S.
# 3                            AVICOLA TRIPLE A S.A.S.
# 4                            AVICOLA TRIPLE A S.A.S.
# ...                                              ...
# 18561                        AVICOLA TRIPLE A S.A.S.
# 18562                        AVICOLA TRIPLE A S.A.S.
# 18563                        AVICOLA TRIPLE A S.A.S.
# 18564  OPERADORA AVICOLA DE COLOMBIA S.A.S TOCANCIPA
# 18565                        AVICOLA TRIPLE A S.A.S.
#
#                   Direccion Remite DANE Remite  Nit Destino  \
# 0                  Boyaca calle 13       11001   9002949239
# 1                  Boyaca calle 13       11001   9002949239
# 2                  Boyaca calle 13       11001   9002949239
# 3                  Boyaca calle 13       11001   9002949239
# 4                  Boyaca calle 13       11001   9002949239
# ...                            ...         ...          ...
# 18561              Boyaca calle 13       11001   9002949239
# 18562              Boyaca calle 13       11001   9002949239
# 18563              Boyaca calle 13       11001   9002949239
# 18564  Parque Industrial del Norte       25817   8914018586
# 18565              Boyaca calle 13       11001   9002949239
#
#                                       Nombre Destino        Direccion Destino  \
# 0                             AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 1                             AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 2                             AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 3                             AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 4                             AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# ...                                              ...                      ...
# 18561                         AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 18562                         AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 18563                         AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
# 18564  OPERADORA AVICOLA DE COLOMBIA S.A.S TOCANCIPA  DISTRIBUCIÃ“N TOCANCIPA
# 18565                         AVICOLA TRIPLE A S.A.S          CALLE 18 69F 86
#
#       DANE Destino  Razon  Observaciones Conductor - Vehículo
# 0            11001    NaN                                   -
# 1            11001    NaN                                   -
# 2            11001    NaN                                   -
# 3            11001    NaN                                   -
# 4            11001    NaN                                   -
# ...            ...    ...                                 ...
# 18561        11001    NaN                                   -
# 18562        11001    NaN                                   -
# 18563        11001    NaN                                   -
# 18564        25817    NaN                                   -
# 18565        11001    NaN                                   -
#
# [18566 rows x 85 columns]

# %% [markdown]
# **Datos potenciales**

# %%
## Tipo de dataset
type(rndc)
# Out:
# pandas.core.frame.DataFrame

# %%
##Dimensiones
rndc.shape
# Out:
# (18566, 85)

# %%
## Filtro de datos relevantes mas la suma de los mismos
print(rndc["Sucursal"].value_counts().head(20))
# Out:
# Sucursal
# OPAV TOCANCIPA          5602
# OPAV FUNZA              3083
# ATA BOGOTA              2969
# OLIMPICO BOGOTA         2741
# MILUC BOGOTA            2262
# OPAV RIONEGRO           1200
# BIGMARKET COTA           292
# OPAV IBAGUE              227
# AGROINDUSTRIA BOGOTA     150
# ANTILLANA TOCANCIPA       40
# Name: count, dtype: int64

# %%
## Opcion 01 para el filtrado de datos relevantes mas la suma de los mismos
rndc["Sucursal"].value_counts().head(20)
# Out:
# Sucursal
# OPAV TOCANCIPA          5602
# OPAV FUNZA              3083
# ATA BOGOTA              2969
# OLIMPICO BOGOTA         2741
# MILUC BOGOTA            2262
# OPAV RIONEGRO           1200
# BIGMARKET COTA           292
# OPAV IBAGUE              227
# AGROINDUSTRIA BOGOTA     150
# ANTILLANA TOCANCIPA       40
# Name: count, dtype: int64

# %%
## Identifacion de columnas de datasets
rndc.columns
# Out:
# Index(['Item', 'Fecha', 'Sucursal', 'Origen', 'Destino', 'Nit', 'Cliente',
#        'Categoria', 'Orden de Servicio', 'Doc. Cliente', 'Doc. Cliente 2',
#        'Mercancia', 'Embalaje', 'Modalidad', 'Descripción Precinto', 'Remesa',
#        'Manifiesto', 'Man.Electronico', 'Póliza Estampilla CHUBB',
#        'Póliza Estampilla Allianz', 'Peso', 'Entregado', 'C.C. Conductor',
#        'Conductor', 'Celular', 'Placa', 'PlacaR', 'Id del Vehiculo',
#        'Tipo Veh.', 'C.C. Tenedor', 'Tenedor', 'C.C. Propietario',
#        'Propietario', 'C.C. Trayler', 'P Trayler', 'Valor Orden',
#        'Costo Orden', 'Comision Orden', 'Rentabilidad', 'Rentabilidad %',
#        'Anticipo', 'Flete Factura', 'Devolucion Factura', 'Acompanante Fctura',
#        'Cargue Fac', 'Descargue Fac', 'Comision Fac', 'Montacarga Fac',
#        'Otros Fac', 'Stand By Fac', 'Seguro Fac', 'Flete Man',
#        'Devolucion Man', 'Seguro Aseg', 'Acompanante Man', 'Cargue Man',
#        'Descargue Man', 'Comision Terc', 'Montacarga Man', 'Otros Man',
#        'Stand by Man', 'Asiscar', 'Inicio Viaje', 'Fin de Viaje',
#        'Fecha Cumplido', 'Fecha Liq.', 'Recibo de Caja', 'Fecha de Pago',
#        'Factura', 'Fecha Recibo de Caja', 'Vr Facturado', 'Fecha Factura',
#        'Fecha Vencimiento', 'Estado', 'Vendedor', 'Nit REmite',
#        'Nombre Remite', 'Direccion Remite', 'DANE Remite', 'Nit Destino',
#        'Nombre Destino', 'Direccion Destino', 'DANE Destino', 'Razon',
#        'Observaciones Conductor - Vehículo'],
#       dtype='object')

# %%
## Filtrado de columnas potenciales
rndc_columns=rndc[["Item","Fecha","Sucursal","Modalidad","Peso","Origen","Destino","Valor Orden","Costo Orden","Rentabilidad","Flete Factura","Factura"]]
rndc_columns
# Out:
#         Item       Fecha        Sucursal Modalidad    Peso     Origen  \
# 0          1   2/01/2024      ATA BOGOTA    Urbano  1353.0     BOGOTA
# 1          2   2/01/2024      ATA BOGOTA    Urbano  1155.0     BOGOTA
# 2          3   2/01/2024      ATA BOGOTA    Urbano  1157.0     BOGOTA
# 3          4   2/01/2024      ATA BOGOTA    Urbano  1352.0     BOGOTA
# 4          5   2/01/2024      ATA BOGOTA    Urbano  1111.0     BOGOTA
# ...      ...         ...             ...       ...     ...        ...
# 18561  18562  31/12/2024      ATA BOGOTA    Urbano  1541.0     BOGOTA
# 18562  18563  31/12/2024      ATA BOGOTA    Urbano  1187.0     BOGOTA
# 18563  18564  31/12/2024      ATA BOGOTA    Urbano  1438.0     BOGOTA
# 18564  18565  31/12/2024  OPAV TOCANCIPA    Urbano  1800.0  TOCANCIPA
# 18565  18566  31/12/2024      ATA BOGOTA    Urbano  1903.0     BOGOTA
#
#          Destino  Valor Orden  Costo Orden Rentabilidad  Flete Factura Factura
# 0         BOGOTA     250000.0     190000.0        60000       250000.0     NaN
# 1         BOGOTA     250000.0     190000.0        60000       250000.0     NaN
# 2         BOGOTA     250000.0     190000.0        60000       250000.0     NaN
# 3         BOGOTA     250000.0     190000.0        60000       250000.0     NaN
# 4         BOGOTA     250000.0     190000.0        60000       250000.0     NaN
# ...          ...          ...          ...          ...            ...     ...
# 18561     BOGOTA     314700.0     242000.0        72700       314700.0     NaN
# 18562     BOGOTA     273200.0     205000.0        68200       273200.0     NaN
# 18563     BOGOTA     314700.0     242000.0        72700       314700.0     NaN
# 18564  TOCANCIPA     427434.0     330000.0        97434       427434.0     NaN
# 18565     BOGOTA     314700.0     242000.0        72700       314700.0     NaN
#
# [18566 rows x 12 columns]

# %%
## con el metodo head se traen el numero indicado de las primeras filas 
rndc_columns.head(20)
# Out:
#     Item      Fecha    Sucursal      Modalidad    Peso  Origen    Destino  \
# 0      1  2/01/2024  ATA BOGOTA         Urbano  1353.0  BOGOTA     BOGOTA
# 1      2  2/01/2024  ATA BOGOTA         Urbano  1155.0  BOGOTA     BOGOTA
# 2      3  2/01/2024  ATA BOGOTA         Urbano  1157.0  BOGOTA     BOGOTA
# 3      4  2/01/2024  ATA BOGOTA         Urbano  1352.0  BOGOTA     BOGOTA
# 4      5  2/01/2024  ATA BOGOTA         Urbano  1111.0  BOGOTA     BOGOTA
# 5      6  2/01/2024  ATA BOGOTA         Urbano  1396.0  BOGOTA     BOGOTA
# 6      7  3/01/2024  ATA BOGOTA         Urbano  1197.0  BOGOTA     BOGOTA
# 7      8  3/01/2024  ATA BOGOTA         Urbano  1188.0  BOGOTA     BOGOTA
# 8      9  3/01/2024  ATA BOGOTA         Urbano  1151.0  BOGOTA     BOGOTA
# 9     10  3/01/2024  ATA BOGOTA  Nacionalizado  2222.0  BOGOTA  ZIPAQUIRA
# 10    11  3/01/2024  ATA BOGOTA         Urbano  1102.0  BOGOTA     BOGOTA
# 11    12  3/01/2024  ATA BOGOTA         Urbano  1115.0  BOGOTA     BOGOTA
# 12    13  3/01/2024  ATA BOGOTA         Urbano  1334.0  BOGOTA     BOGOTA
# 13    14  3/01/2024  ATA BOGOTA  Nacionalizado  1311.0  BOGOTA     MADRID
# 14    15  4/01/2024  ATA BOGOTA         Urbano  1169.0  BOGOTA     BOGOTA
# 15    16  4/01/2024  ATA BOGOTA         Urbano  1182.0  BOGOTA     BOGOTA
# 16    17  4/01/2024  ATA BOGOTA         Urbano  1141.0  BOGOTA     BOGOTA
# 17    18  4/01/2024  ATA BOGOTA         Urbano  1247.0  BOGOTA     BOGOTA
# 18    19  4/01/2024  ATA BOGOTA         Urbano  1147.0  BOGOTA     BOGOTA
# 19    20  4/01/2024  ATA BOGOTA         Urbano  1389.0  BOGOTA     BOGOTA
#
#     Valor Orden  Costo Orden Rentabilidad  Flete Factura Factura
# 0      250000.0     190000.0        60000       250000.0     NaN
# 1      250000.0     190000.0        60000       250000.0     NaN
# 2      250000.0     190000.0        60000       250000.0     NaN
# 3      250000.0     190000.0        60000       250000.0     NaN
# 4      250000.0     190000.0        60000       250000.0     NaN
# 5      250000.0     190000.0        60000       250000.0     NaN
# 6      250000.0     190000.0        60000       250000.0     NaN
# 7      250000.0     190000.0        60000       250000.0     NaN
# 8      250000.0     190000.0        60000       250000.0     NaN
# 9      340000.0     280000.0        60000       340000.0     NaN
# 10     250000.0     190000.0        60000       250000.0     NaN
# 11     250000.0     190000.0        60000       250000.0     NaN
# 12     250000.0     190000.0        60000       250000.0     NaN
# 13     250000.0     200000.0        50000       250000.0     NaN
# 14     250000.0     190000.0        60000       250000.0     NaN
# 15     250000.0     190000.0        60000       250000.0     NaN
# 16     250000.0     190000.0        60000       250000.0     NaN
# 17     250000.0     190000.0        60000       250000.0     NaN
# 18     250000.0     190000.0        60000       250000.0     NaN
# 19     250000.0     190000.0        60000       250000.0     NaN

# %%
## con el metodo tail traemos el numero de filas indicados de las ultimas filas 
rndc_columns.tail(20)
# Out:
#         Item       Fecha         Sucursal      Modalidad    Peso     Origen  \
# 18546  18547  31/12/2024  OLIMPICO BOGOTA  Nacionalizado   501.8     BOGOTA
# 18547  18548  31/12/2024  OLIMPICO BOGOTA         Urbano   719.8     BOGOTA
# 18548  18549  31/12/2024  OLIMPICO BOGOTA         Urbano  1439.6     BOGOTA
# 18549  18550  31/12/2024  OLIMPICO BOGOTA         Urbano  1230.0     BOGOTA
# 18550  18551  31/12/2024  OLIMPICO BOGOTA         Urbano  1731.4     BOGOTA
# 18551  18552  31/12/2024  OLIMPICO BOGOTA  Nacionalizado  1443.4     BOGOTA
# 18552  18553  31/12/2024  OLIMPICO BOGOTA         Urbano  2203.2     BOGOTA
# 18553  18554  31/12/2024  OLIMPICO BOGOTA         Urbano  1338.4     BOGOTA
# 18554  18555  28/12/2024     MILUC BOGOTA         Urbano  2598.7     BOGOTA
# 18555  18556  30/12/2024     MILUC BOGOTA         Urbano  1647.0     BOGOTA
# 18556  18557  31/12/2024     MILUC BOGOTA         Urbano  1200.4     BOGOTA
# 18557  18558  31/12/2024       ATA BOGOTA         Urbano  1131.0     BOGOTA
# 18558  18559  31/12/2024       ATA BOGOTA         Urbano  1394.0     BOGOTA
# 18559  18560  31/12/2024       ATA BOGOTA         Urbano  1177.0     BOGOTA
# 18560  18561  31/12/2024       ATA BOGOTA         Urbano  1541.0     BOGOTA
# 18561  18562  31/12/2024       ATA BOGOTA         Urbano  1541.0     BOGOTA
# 18562  18563  31/12/2024       ATA BOGOTA         Urbano  1187.0     BOGOTA
# 18563  18564  31/12/2024       ATA BOGOTA         Urbano  1438.0     BOGOTA
# 18564  18565  31/12/2024   OPAV TOCANCIPA         Urbano  1800.0  TOCANCIPA
# 18565  18566  31/12/2024       ATA BOGOTA         Urbano  1903.0     BOGOTA
#
#           Destino  Valor Orden  Costo Orden Rentabilidad  Flete Factura  \
# 18546  FACATATIVA    160617.66          0.0    160617.66      160617.66
# 18547      BOGOTA    146119.40     284000.0    -137880.6      146119.40
# 18548      BOGOTA    289676.94     284000.0      5676.94      289676.94
# 18549      BOGOTA    241884.65     284000.0    -42115.35      241884.65
# 18550      BOGOTA    347333.00     284000.0        63333      347333.00
# 18551      SOACHA    280661.71     330000.0    -49338.29      280661.71
# 18552      BOGOTA    441188.02     284000.0    157188.02      441188.02
# 18553      BOGOTA    268885.68     284000.0    -15114.32      268885.68
# 18554      BOGOTA    405736.10     299870.0     105866.1      405736.10
# 18555      BOGOTA    333346.30     270000.0      63346.3      333346.30
# 18556      BOGOTA    242909.80     270000.0     -27090.2      242909.80
# 18557      BOGOTA    273200.00     205000.0        68200      273200.00
# 18558      BOGOTA    314700.00     242000.0        72700      314700.00
# 18559      BOGOTA    314700.00     242000.0        72700      314700.00
# 18560      BOGOTA    314700.00     242000.0        72700      314700.00
# 18561      BOGOTA    314700.00     242000.0        72700      314700.00
# 18562      BOGOTA    273200.00     205000.0        68200      273200.00
# 18563      BOGOTA    314700.00     242000.0        72700      314700.00
# 18564   TOCANCIPA    427434.00     330000.0        97434      427434.00
# 18565      BOGOTA    314700.00     242000.0        72700      314700.00
#
#        Factura
# 18546  STBG401
# 18547  STBG401
# 18548  STBG401
# 18549  STBG401
# 18550  STBG401
# 18551  STBG401
# 18552  STBG401
# 18553  STBG401
# 18554  STBG407
# 18555  STBG407
# 18556  STBG407
# 18557      NaN
# 18558      NaN
# 18559      NaN
# 18560      NaN
# 18561      NaN
# 18562      NaN
# 18563      NaN
# 18564      NaN
# 18565      NaN

# %%
## Filtrado de dastos unicos
rndc["Sucursal"].unique()
# Out:
# array(['ATA BOGOTA', 'OPAV FUNZA', 'OPAV RIONEGRO', 'BIGMARKET COTA',
#        'OPAV IBAGUE', 'MILUC BOGOTA', 'OLIMPICO BOGOTA',
#        'AGROINDUSTRIA BOGOTA', 'OPAV TOCANCIPA', 'ANTILLANA TOCANCIPA'],
#       dtype=object)

# %%
## suma de viajes echos por cada ciudad segun el numero indicado
rndc['Destino'].value_counts().head(20)
# Out:
# Destino
# BOGOTA               13359
# SOACHA                 977
# FACATATIVA             796
# RIONEGRO               620
# FUNZA                  447
# IBAGUE                 285
# ZIPAQUIRA              225
# VILLAVICENCIO          180
# TUNJA                  163
# CHIA                   161
# TOCANCIPA              157
# MOSQUERA               153
# MADRID                 144
# CAJICA                 113
# GUATAPE                 94
# CARMEN DE VIBORAL       92
# SANTUARIO               91
# LA CEJA                 90
# EL RETIRO               89
# MARINILLA               76
# Name: count, dtype: int64
